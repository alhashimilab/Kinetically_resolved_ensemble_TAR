# %%
# import required libraries
import os, sys
import numpy as np, pandas as pd, seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
from sklearn.metrics import r2_score
import matplotlib.lines as mlines
import warnings
warnings.filterwarnings('ignore')
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42
mpl.rcParams['font.family'] = 'Arial'
sns.set_context('poster')

# %%
## Plot RMSD Trends:
pool_rmsd = [0.92, 0.2, 0.85, 1.01, 0.78, 0.81, 0.65, 0.81, 0.37, 0.34]
ens_rmsd =  [0.89, 0.22, 0.79, 0.86, 0.59, 0.55, 0.58, 0.68, 0.34, 0.23]
low_rmsd =  [1.04, 0.22, 1.59, 1.09, 0.95, 1.16, 0.82, 0.43, 0.80, 0.36]

fig, ax = plt.subplots()
fig.set_size_inches(12,4)
    
xticklabels = ["C1'", "C2'", "C3'", "C4'", "C5'", "C8", "C6", "C5", "C2", "N1/N3"]
xticks = list(range(1, len(xticklabels)+1))
xticks1 = np.array(xticks) - 0.25
xticks2 = np.array(xticks) 
xticks3 = np.array(xticks) + 0.25

ax.bar(x = xticks1, height=pool_rmsd, color="blue", width=0.22)
ax.bar(x = xticks2, height=ens_rmsd, color="red", width=0.22)
ax.bar(x = xticks3, height=low_rmsd, color="orange", width=0.22)

#ax.tick_params(width=2,length=6)
#ax.tick_params(axis='both', which='major', labelsize=20)
ax.set_ylim([0, 1.7])
ax.set_xlim([0.5, 10.5])
ax.set_xticks(xticks)
ax.set_xticklabels(xticklabels, fontsize = 20)
ax.set_ylabel(r"RMSD (ppm)", fontsize=20)
#ax.axhline(y=error_EII3, ls = '--', color='k')
ax.tick_params(width=2,length=6)
plt.savefig("plots/Final_CS_RMSD_Ens_Trends.pdf")
plt.show()

# %%
## Plot RMSD Trends:
pool_r2 = [0.58, 0.45, 0.76, 0.17, 0.54, 0.83, 0.38, 0.94, 0.77, 1.0]
ens_r2 =  [0.63, 0.38, 0.80, 0.37, 0.73, 0.9, 0.3, 0.95, 0.61, 1.0]
low_r2 =  [0.47, 0.36, 0.14, 0.03, 0.31, 0.66, 0.01, 0.94, 0.68, 1.0]

fig, ax = plt.subplots()
fig.set_size_inches(12,4)
    
xticklabels = ["C1'", "C2'", "C3'", "C4'", "C5'", "C8", "C6", "C5", "C2", "N1/N3"]
xticks = list(range(1, len(xticklabels)+1))
xticks1 = np.array(xticks) - 0.25
xticks2 = np.array(xticks) 
xticks3 = np.array(xticks) + 0.25

ax.bar(x = xticks1, height=pool_r2, color="blue", width=0.22)
ax.bar(x = xticks2, height=ens_r2, color="red", width=0.22)
ax.bar(x = xticks3, height=low_r2, color="orange", width=0.22)

#ax.tick_params(width=2,length=6)
#ax.tick_params(axis='both', which='major', labelsize=20)
ax.set_ylim([0, 1.0])
ax.set_xlim([0.5, 10.5])
ax.set_xticks(xticks)
ax.set_xticklabels(xticklabels, fontsize = 20)
ax.set_ylabel(r"RMSD (ppm)", fontsize=20)
#ax.axhline(y=error_EII3, ls = '--', color='k')
ax.tick_params(width=2,length=6)
plt.savefig("plots/Final_CS_R2_Ens_Trends.pdf")
plt.show()

# %%
## Plot R2 Trends:
pool_rmsd = [0.58, 0.45, 0.76, 0.17, 0.54, 0.83, 0.38, 0.94, 0.77, 1.0]
ens_rmsd =  [0.61, 0.36, 0.79, 0.39, 0.73, 0.92, 0.52, 0.96, 0.8, 1.0]
fig, ax = plt.subplots()
fig.set_size_inches(12,4)
    
xticklabels = ["C1'", "C2'", "C3'", "C4'", "C5'", "C8", "C6", "C5", "C2", "N1/N3"]
xticks = list(range(1, len(xticklabels)+1))
xticks1 = np.array(xticks) - 0.2
xticks2 = np.array(xticks) + 0.2

ax.bar(x = xticks1, height=pool_rmsd, color="blue", width=0.3)
ax.bar(x = xticks2, height=ens_rmsd, color="red", width=0.3)

#ax.tick_params(width=2,length=6)
#ax.tick_params(axis='both', which='major', labelsize=20)
ax.set_ylim([0, 1])
ax.set_xlim([0.5, 10.5])
ax.set_xticks(xticks)
ax.set_xticklabels(xticklabels, fontsize = 20)
ax.set_ylabel(r"$R^2$ (ppm)", fontsize=20)
#ax.axhline(y=error_EII3, ls = '--', color='k')
ax.tick_params(width=2,length=6)
plt.savefig("plots/R2_Pool_Ens_Trends.pdf")

# %%
## Plot RMSD Trends:
pB = [13, 17, 0]
pB_error =  [2, 4,  0]
fig, ax = plt.subplots()
fig.set_size_inches(5,4)
    
xticklabels = ["1", "2", "3"]
xticks = list(range(1, len(xticklabels)+1))


ax.bar(x = xticks, height=pB, yerr=pB_error, color="blue", capsize=6, width=0.5)


#ax.tick_params(width=2,length=6)
#ax.tick_params(axis='both', which='major', labelsize=20)
ax.set_ylim([0, 25])
ax.set_xlim([0.5, 3.5])
ax.set_xticks(xticks)
ax.set_xticklabels(xticklabels, fontsize = 20)
#ax.set_ylabel(r"RMSD (ppm)", fontsize=20)
#ax.axhline(y=error_EII3, ls = '--', color='k')
ax.tick_params(width=2,length=6)
plt.savefig("plots/pB_trend.pdf")

# %%
pool_rmsd = [0.92, 0.2, 0.85, 1.01, 0.78, 0.81, 0.65, 0.81, 0.37, 0.34]
pool_rmsd_h=[0.15, 0.13, 0.11, 0.13, 0.18, 0.19, 0.11, 0.31, 0.17, 0.24]

ens_rmsd =  [0.89, 0.22, 0.79, 0.86, 0.59, 0.55, 0.58, 0.68, 0.34, 0.23]
ens_rmsd_h=[0.14, 0.12, 0.11, 0.12, 0.13, 0.18, 0.11, 0.23, 0.16, 0.17]

low_rmsd =  [1.04, 0.22, 1.59, 1.09, 0.95, 1.16, 0.82, 0.43, 0.80, 0.36]
low_rmsd_h=[0.17, 0.17, 0.15, 0.13, 0.18, 0.19, 0.12, 0.32, 0.19, 0.17]

# %%
fig, ax = plt.subplots()
fig.set_size_inches(8,3)
    
xticklabels = ["C1'", "C2'", "C3'", "C4'", "C5'", "C8", "C6", "C5", "C2", "N1/N3"]
xticks = list(range(1, len(xticklabels)+1))

ax.bar(x = xticks, height=pool_rmsd, color="blue", width=0.6)

#ax.tick_params(width=2,length=6)
#ax.tick_params(axis='both', which='major', labelsize=20)
ax.set_ylim([0, 1.1])
ax.set_xlim([0.5, 10.5])
ax.set_xticks(xticks)
ax.set_xticklabels(xticklabels, fontsize = 16)
ax.set_ylabel(r"RMSD (ppm)", fontsize=20)
#ax.axhline(y=error_EII3, ls = '--', color='k')
ax.tick_params(width=2,length=6)
plt.savefig("plots/RMSD_Pool_Trends.pdf")

fig, ax = plt.subplots()
fig.set_size_inches(8,3)
    
xticklabels = ["H1'", "H2'", "H3'", "H4'", "H5'", "H8", "H6", "H5", "H2", "H1/H3"]
xticks = list(range(1, len(xticklabels)+1))

ax.bar(x = xticks, height=pool_rmsd_h, color="blue", width=0.6)

#ax.tick_params(width=2,length=6)
#ax.tick_params(axis='both', which='major', labelsize=20)
ax.set_ylim([0, 0.32])
ax.set_xlim([0.5, 10.5])
ax.set_xticks(xticks)
ax.set_xticklabels(xticklabels, fontsize = 16)
ax.set_ylabel(r"RMSD (ppm)", fontsize=20)
#ax.axhline(y=error_EII3, ls = '--', color='k')
ax.tick_params(width=2,length=6)
plt.savefig("plots/RMSD_Pool_Trends_H.pdf")

# %%
fig, ax = plt.subplots()
fig.set_size_inches(8,3)
    
xticklabels = ["H1'", "H2'", "H3'", "H4'", "H5'", "H8", "H6", "H5", "H2", "H1/H3"]
xticks = list(range(1, len(xticklabels)+1))

ax.bar(x = xticks, height=ens_rmsd_h, color="red", width=0.6)

#ax.tick_params(width=2,length=6)
#ax.tick_params(axis='both', which='major', labelsize=20)
ax.set_ylim([0, 0.25])
ax.set_xlim([0.5, 10.5])
ax.set_xticks(xticks)
ax.set_xticklabels(xticklabels, fontsize = 16)
ax.set_ylabel(r"RMSD (ppm)", fontsize=20)
#ax.axhline(y=error_EII3, ls = '--', color='k')
ax.tick_params(width=2,length=6)
plt.savefig("plots/RMSD_Ens_Trends_H.pdf")

fig, ax = plt.subplots()
fig.set_size_inches(8,3)
    
xticklabels = ["C1'", "C2'", "C3'", "C4'", "C5'", "C8", "C6", "C5", "C2", "N1/N3"]
xticks = list(range(1, len(xticklabels)+1))

ax.bar(x = xticks, height=ens_rmsd, color="red", width=0.6)

#ax.tick_params(width=2,length=6)
#ax.tick_params(axis='both', which='major', labelsize=20)
ax.set_ylim([0, 1.1])
ax.set_xlim([0.5, 10.5])
ax.set_xticks(xticks)
ax.set_xticklabels(xticklabels, fontsize = 16)
ax.set_ylabel(r"RMSD (ppm)", fontsize=20)
#ax.axhline(y=error_EII3, ls = '--', color='k')
ax.tick_params(width=2,length=6)
plt.savefig("plots/RMSD_Ens_Trends.pdf")

# %%
fig, ax = plt.subplots()
fig.set_size_inches(8,3)
    
xticklabels = ["C1'", "C2'", "C3'", "C4'", "C5'", "C8", "C6", "C5", "C2", "N1/N3"]
xticks = list(range(1, len(xticklabels)+1))

ax.bar(x = xticks, height=low_rmsd, color="green", width=0.6)

#ax.tick_params(width=2,length=6)
#ax.tick_params(axis='both', which='major', labelsize=20)
ax.set_ylim([0, 1.7])
ax.set_xlim([0.5, 10.5])
ax.set_xticks(xticks)
ax.set_xticklabels(xticklabels, fontsize = 16)
ax.set_ylabel(r"RMSD (ppm)", fontsize=20)
#ax.axhline(y=error_EII3, ls = '--', color='k')
ax.tick_params(width=2,length=6)
plt.savefig("plots/RMSD_LowestEnergy_Trends.pdf")

fig, ax = plt.subplots()
fig.set_size_inches(8,3)
    
xticklabels = ["H1'", "H2'", "H3'", "H4'", "H5'", "H8", "H6", "H5", "H2", "H1/H3"]
xticks = list(range(1, len(xticklabels)+1))

ax.bar(x = xticks, height=low_rmsd_h, color="green", width=0.6)

#ax.tick_params(width=2,length=6)
#ax.tick_params(axis='both', which='major', labelsize=20)
ax.set_ylim([0, 0.35])
ax.set_xlim([0.5, 10.5])
ax.set_xticks(xticks)
ax.set_xticklabels(xticklabels, fontsize = 16)
ax.set_ylabel(r"RMSD (ppm)", fontsize=20)
#ax.axhline(y=error_EII3, ls = '--', color='k')
ax.tick_params(width=2,length=6)
plt.savefig("plots/RMSD_LowestEnergy_Trends_H.pdf")

# %%
pool_r =  [0.58, 0.45, 0.76, 0.17, 0.54, 0.83, 0.38, 0.77, 0.94, 1.00]
pool_r_h= [0.29, 0.56, 0.48, 0.00, 0.30, 0.67, 0.40, 0.51, 0.55, 0.78]

ens_r =   [0.63, 0.38, 0.80, 0.37, 0.73, 0.90, 0.30, 0.62, 0.95, 1.00]
ens_r_h=  [0.38, 0.63, 0.44, 0.08, 0.64, 0.70, 0.43, 0.73, 0.59, 0.89]

low_r =   [0.47, 0.36, 0.14, 0.03, 0.31, 0.66, 0.01, 0.68, 0.94, 1.00]
low_r_h=  [0.14, 0.27, 0.01, 0.03, 0.25, 0.67, 0.27, 0.48, 0.44, 0.89]

# %%
fig, ax = plt.subplots()
fig.set_size_inches(8,3)
    
xticklabels = ["C1'", "C2'", "C3'", "C4'", "C5'", "C8", "C6", "C5", "C2", "N1/N3"]
xticks = list(range(1, len(xticklabels)+1))

ax.bar(x = xticks, height=pool_r, color="blue", width=0.6)

#ax.tick_params(width=2,length=6)
#ax.tick_params(axis='both', which='major', labelsize=20)
ax.set_ylim([0, 1])
ax.set_xlim([0.5, 10.5])
ax.set_xticks(xticks)
ax.set_xticklabels(xticklabels, fontsize = 16)
ax.set_ylabel(r"R2", fontsize=20)
#ax.axhline(y=error_EII3, ls = '--', color='k')
ax.tick_params(width=2,length=6)
plt.savefig("plots/R2_Pool_Trends.pdf")

fig, ax = plt.subplots()
fig.set_size_inches(8,3)
    
xticklabels = ["H1'", "H2'", "H3'", "H4'", "H5'", "H8", "H6", "H5", "H2", "H1/H3"]
xticks = list(range(1, len(xticklabels)+1))

ax.bar(x = xticks, height=pool_r_h, color="blue", width=0.6)

#ax.tick_params(width=2,length=6)
#ax.tick_params(axis='both', which='major', labelsize=20)
ax.set_ylim([0, 1])
ax.set_xlim([0.5, 10.5])
ax.set_xticks(xticks)
ax.set_xticklabels(xticklabels, fontsize = 16)
ax.set_ylabel(r"R2", fontsize=20)
#ax.axhline(y=error_EII3, ls = '--', color='k')
ax.tick_params(width=2,length=6)
plt.savefig("plots/R2_Pool_Trends_H.pdf")

# %%
fig, ax = plt.subplots()
fig.set_size_inches(8,3)
    
xticklabels = ["H1'", "H2'", "H3'", "H4'", "H5'", "H8", "H6", "H5", "H2", "H1/H3"]
xticks = list(range(1, len(xticklabels)+1))

ax.bar(x = xticks, height=ens_r_h, color="red", width=0.6)

#ax.tick_params(width=2,length=6)
#ax.tick_params(axis='both', which='major', labelsize=20)
ax.set_ylim([0, 1])
ax.set_xlim([0.5, 10.5])
ax.set_xticks(xticks)
ax.set_xticklabels(xticklabels, fontsize = 16)
ax.set_ylabel(r"R2", fontsize=20)
#ax.axhline(y=error_EII3, ls = '--', color='k')
ax.tick_params(width=2,length=6)
plt.savefig("plots/R2_Ens_Trends_H.pdf")

fig, ax = plt.subplots()
fig.set_size_inches(8,3)
    
xticklabels = ["C1'", "C2'", "C3'", "C4'", "C5'", "C8", "C6", "C5", "C2", "N1/N3"]
xticks = list(range(1, len(xticklabels)+1))

ax.bar(x = xticks, height=ens_r, color="red", width=0.6)

#ax.tick_params(width=2,length=6)
#ax.tick_params(axis='both', which='major', labelsize=20)
ax.set_ylim([0, 1])
ax.set_xlim([0.5, 10.5])
ax.set_xticks(xticks)
ax.set_xticklabels(xticklabels, fontsize = 16)
ax.set_ylabel(r"R2", fontsize=20)
#ax.axhline(y=error_EII3, ls = '--', color='k')
ax.tick_params(width=2,length=6)
plt.savefig("plots/R2_Ens_Trends.pdf")

# %%
fig, ax = plt.subplots()
fig.set_size_inches(8,3)
    
xticklabels = ["C1'", "C2'", "C3'", "C4'", "C5'", "C8", "C6", "C5", "C2", "N1/N3"]
xticks = list(range(1, len(xticklabels)+1))

ax.bar(x = xticks, height=low_r, color="green", width=0.6)

#ax.tick_params(width=2,length=6)
#ax.tick_params(axis='both', which='major', labelsize=20)
ax.set_ylim([0, 1])
ax.set_xlim([0.5, 10.5])
ax.set_xticks(xticks)
ax.set_xticklabels(xticklabels, fontsize = 16)
ax.set_ylabel(r"R2", fontsize=20)
#ax.axhline(y=error_EII3, ls = '--', color='k')
ax.tick_params(width=2,length=6)
plt.savefig("plots/R2_LowestEnergy_Trends.pdf")

fig, ax = plt.subplots()
fig.set_size_inches(8,3)
    
xticklabels = ["H1'", "H2'", "H3'", "H4'", "H5'", "H8", "H6", "H5", "H2", "H1/H3"]
xticks = list(range(1, len(xticklabels)+1))

ax.bar(x = xticks, height=low_r_h, color="green", width=0.6)

#ax.tick_params(width=2,length=6)
#ax.tick_params(axis='both', which='major', labelsize=20)
ax.set_ylim([0, 1])
ax.set_xlim([0.5, 10.5])
ax.set_xticks(xticks)
ax.set_xticklabels(xticklabels, fontsize = 16)
ax.set_ylabel(r"R2", fontsize=20)
#ax.axhline(y=error_EII3, ls = '--', color='k')
ax.tick_params(width=2,length=6)
plt.savefig("plots/R2_LowestEnergy_Trends_H.pdf")
